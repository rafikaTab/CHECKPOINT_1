# %% [markdown]
# <a href="https://colab.research.google.com/github/rafikaTab/CHECKPOINT_1/blob/master/K-means%20%26%20Hierarchical%20Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1-Load DATASET**

# %%
import pandas as pd

df=pd.read_csv('CC GENERAL.csv',sep=',')

# %%
df
# Out:
#      CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0     C10001    40.900749  ...          0.000000      12
# 1     C10002  3202.467416  ...          0.222222      12
# 2     C10003  2495.148862  ...          0.000000      12
# 3     C10004  1666.670542  ...          0.000000      12
# 4     C10005   817.714335  ...          0.000000      12
# ...      ...          ...  ...               ...     ...
# 8945  C19186    28.493517  ...          0.500000       6
# 8946  C19187    19.183215  ...          0.000000       6
# 8947  C19188    23.398673  ...          0.250000       6
# 8948  C19189    13.457564  ...          0.250000       6
# 8949  C19190   372.708075  ...          0.000000       6
#
# [8950 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
df["MINIMUM_PAYMENTS"].value_counts()
# Out:
# 299.351881     2
# 3.197940       1
# 111.691332     1
# 129.682608     1
# 872.760983     1
#               ..
# 1227.773229    1
# 127.210691     1
# 6422.472544    1
# 471.940554     1
# 189.459157     1
# Name: MINIMUM_PAYMENTS, Length: 8636, dtype: int64

# %% [markdown]
# **2- hierarchical clustering**

# %%
#import pandas as pd
#data=pd.read_csv("Mall_Customers.csv")

data=df.drop("CUST_ID", axis=1)
#df["CUST_ID"]=data["Gender"].map({"Male":1, "Female":0})  #convert Gender values into numerical
data
# Out:
#           BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE
# 0       40.900749           0.818182  ...          0.000000      12
# 1     3202.467416           0.909091  ...          0.222222      12
# 2     2495.148862           1.000000  ...          0.000000      12
# 3     1666.670542           0.636364  ...          0.000000      12
# 4      817.714335           1.000000  ...          0.000000      12
# ...           ...                ...  ...               ...     ...
# 8945    28.493517           1.000000  ...          0.500000       6
# 8946    19.183215           1.000000  ...          0.000000       6
# 8947    23.398673           0.833333  ...          0.250000       6
# 8948    13.457564           0.833333  ...          0.250000       6
# 8949   372.708075           0.666667  ...          0.000000       6
#
# [8950 rows x 17 columns]

# %%
from sklearn.cluster import AgglomerativeClustering #Importing our clustering algorithm : Agglomerative
model=AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
clust_labels=model.fit_predict(data)  #Applying agglomerative algorithm with 5 clusters, using euclidean distance as a metric
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-81dbd47f391e> in <module>()
#       1 from sklearn.cluster import AgglomerativeClustering #Importing our clustering algorithm : Agglomerative
#       2 model=AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
# ----> 3 clust_labels=model.fit_predict(data)  #Applying agglomerative algorithm with 5 clusters, using euclidean distance as a metric
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_agglomerative.py in fit_predict(self, X, y)
#     900             Cluster labels.
#     901         """
# --> 902         return super().fit_predict(X, y)
#     903
#     904
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in fit_predict(self, X, y)
#     460         # non-optimized default implementation; override when a better
#     461         # method is possible for a given clustering algorithm
# --> 462         self.fit(X)
#     463         return self.labels_
#     464
#
# /usr/local/lib/python3.6/dist-packages/sklearn/cluster/_agglomerative.py in fit(self, X, y)
#     794         self
#     795         """
# --> 796         X = check_array(X, ensure_min_samples=2, estimator=self)
#     797         memory = check_memory(self.memory)
#     798
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     576         if force_all_finite:
#     577             _assert_all_finite(array,
# --> 578                                allow_nan=force_all_finite == 'allow-nan')
#     579
#     580     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      58                     msg_err.format
#      59                     (type_err,
# ---> 60                      msg_dtype if msg_dtype is not None else X.dtype)
#      61             )
#      62     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
agglomerative=pd.DataFrame(clust_labels)
agglomerative

# %% [markdown]
# **Agglomerative cluster plot**

# %%
import matplotlib.pyplot as plt
fig =plt.figure()
ax = fig.add_subplot(111)
scatter = ax.scatter (data ['Annual Income (k$)'] , data ["Spending Score (1-100)"] , c= agglomerative[0], s=50)
ax.set_title("Agglomerative Clutering")
ax.set_xlabel("Annual Income (k$)")
ax.set_ylabel("Spending Score (1-100)")
plt.colorbar(scatter)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Annual Income (k$)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-0ae0a93068b0> in <module>()
#       2 fig =plt.figure()
#       3 ax = fig.add_subplot(111)
# ----> 4 scatter = ax.scatter (data ['Annual Income (k$)'] , data ["Spending Score (1-100)"] , c= agglomerative[0], s=50)
#       5 ax.set_title("Agglomerative Clutering")
#       6 ax.set_xlabel("Annual Income (k$)")
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Annual Income (k$)'

# %% [markdown]
# **Dendrogram Example**

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(data, method="complete"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-5c8793b63821> in <module>()
#       3 plt.figure(figsize=(10,7))
#       4 plt.title("Customer Dendrograms")
# ----> 5 dend=shc.dendrogram(shc.linkage(data, method="complete"))
#
# /usr/local/lib/python3.6/dist-packages/scipy/cluster/hierarchy.py in linkage(y, method, metric, optimal_ordering)
#    1059
#    1060     if not np.all(np.isfinite(y)):
# -> 1061         raise ValueError("The condensed distance matrix must contain only "
#    1062                          "finite values.")
#    1063
#
# ValueError: The condensed distance matrix must contain only finite values.
